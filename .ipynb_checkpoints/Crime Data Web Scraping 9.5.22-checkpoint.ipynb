# %%
'''Import necessary libraries'''
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import mechanicalsoup as ms
import re
import polling2, time
import os, glob
import math

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

from PyPDF2 import PdfReader as pypdf

# %%
'''Retrieve webpage info for landing page for Wilmington, NC crime reports'''
url = 'http://p2c.wilmingtonnc.gov/Summary_Disclaimer.aspx'

'''Open browser with URL'''
browser = ms.StatefulBrowser()

#get page
browser.open(url)
#find all forms on page Note....browser.page in a bs4 object
browser.select_form('form[action="./Summary_Disclaimer.aspx"]')

# %%
'''Submit initial page'''
response = browser.submit_selected()
print(response.text)

# %%
'''Select form from main page'''
browser.select_form()
browser.form.print_summary()

# %%
browser.page.find_all('input')[3]['unchecked'] = ''
browser["MasterPage$mainContent$txtDateFrom2"] = '5/1/2022'
browser["MasterPage$mainContent$CGeoCityDDL12"] = 'WILMINGTON'
browser["MasterPage$mainContent$ddlRange2"] = '0.378788'
browser["MasterPage$mainContent$txtStreetNo2"] = '319'
browser["MasterPage$mainContent$txtStreetName2"] = 'ANDERSON ST'

# %%
browser.launch_browser()

# %%
response = browser.submit_selected()

# %%
response.soup

# %%
browser.close()

# %% [markdown]
# ## Same thing as above with Selenium

# %%
'''Declare driver and get initial webpage'''
url = 'http://p2c.wilmingtonnc.gov/Summary_Disclaimer.aspx'

options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
download_directory = r'C:\Users\scott\Data Projects\Crime Stats\pdf_files'
p = {'download.default_directory': download_directory}
options.add_experimental_option("prefs", p)

driver = webdriver.Chrome(options=options, service=Service(ChromeDriverManager().install()))
driver.get(url)
print(driver.page_source)
# Out:
# <html><head><meta http-equiv="Page-Enter" content="Alpha(opacity=100)"><meta http-equiv="content-type" content="text/html; charset=utf-8"><link id="activeStylesheetLink" href="css/active.css" rel="Stylesheet"><link id="commonStylesheet" href="css/p2cBase.css" rel="Stylesheet"><link rel="Shortcut Icon" href="./images/favicon.ico" type="image/x-icon"><script src="js/jquery-1.8.3.min.js" type="text/javascript"></script><script src="jqui/1.8/jquery-ui-1.8.custom.min.js" type="text/javascript"></script><link href="jqui/1.8/black-tie/jquery-ui.css" rel="Stylesheet" class="ui-theme"><link href="jqui/1.8/black-tie/theme.css" rel="Stylesheet" class="ui-theme">
#
# <link id="jquiOverride" href="css/jqui-override.css" rel="Stylesheet">
#     <script language="javascript" type="text/javascript">
#         // DO NOT REMOVE
#         // this function is used by the form builder
#         // to control tab index issues
#         function getASPElm(nm, tag) {
#             if ($get(nm)) { return $get(nm); }
#             if (!tag) { tag = '*'; }
#             var e = document.getElementsByTagName(tag);
#             for (var i = 0; i < e.length; i++) {
#                 if (e[i].id) {
#                     if (e[i].id.indexOf(nm) != -1) {
#                         return e[i];
#                     }
#                 }
#             }
#             return null;
#         }
#
#         $(document).ready(function () {
#             $("input").attr("autocomplete", "off");
#         });
#     </script>
#
#     <!-- JQuery Menu Helper Script -->
#
#     <!-- JQuery Menu Helper Script -->
# <title>
# 	Wilmington Police Department P2C
# </title></head>
#
# <body class="Body">
#     <script language="javascript" type="text/javascript">
#         $(function () {
#             var backgrounds = [
#
#             ];
#
#             var path = '';
#             var $body = $(document.body);
#             backgrounds.forEach(function (background, index) {
#                 var $element = $('<div class="background-image toggle-image' + (index === 0 ? ' show' : '') + '" style="background-image: url(\''+ path + '/images/background/' + background + '\'); z-index: -' + index + 1 + ';" ></div>');
#                 $body.append($element);
#             });
#
#             (function () {
#                 if (backgrounds.length > 1) {
#                     var index = 0;
#
#                     $imageElements = $('.toggle-image'); // Get the images to be cycled.
#
#                     setInterval(function () {
#                         index = index + 1 < $imageElements.length ? index + 1 : 0;
#                         $imageElements.eq(index - 1).removeClass('show');
#                         $imageElements.eq(index).addClass('show');
#                     }, 18000);
#                 }
#             })();
#         });
#     </script>
#     <form method="post" action="./Summary_Disclaimer.aspx" id="Form1" onsubmit="return(onsubmitEventsHandler());">
# <div class="aspNetHidden">
# <input type="hidden" name="_popupBlockerExists" id="_popupBlockerExists" value="false" autocomplete="off">
# <input type="hidden" name="__EVENTTARGET" id="__EVENTTARGET" value="" autocomplete="off">
# <input type="hidden" name="__EVENTARGUMENT" id="__EVENTARGUMENT" value="" autocomplete="off">
# <input type="hidden" name="__LASTFOCUS" id="__LASTFOCUS" value="" autocomplete="off">
# <input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." autocomplete="off">
# </div>
#
# <script type="text/javascript">
# //<![CDATA[
# var theForm = document.forms['Form1'];
# if (!theForm) {
#     theForm = document.Form1;
# }
# function __doPostBack(eventTarget, eventArgument) {
#     if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
#         theForm.__EVENTTARGET.value = eventTarget;
#         theForm.__EVENTARGUMENT.value = eventArgument;
#         theForm.submit();
#     }
# }
# //]]>
# </script>
#
#
#
# <script src="TinyMCE.ashx?module=GzipModule&amp;themes=advanced&amp;plugins=spellchecker,style,table,save,advlink,preview,media,searchreplace,contextmenu,paste,fullscreen,visualchars,nonbreaking&amp;languages=en" type="text/javascript"></script>
# 	<div class="aspNetHidden">
#
# 		<input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="27903AD3" autocomplete="off">
# 		<input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="" autocomplete="off">
# 	</div>
#
#
#         <table class="MainTable" id="Table1" cellspacing="0" cellpadding="0">
#             <tbody><tr height="40px">
#                 <td valign="bottom" align="left">
#                     <div id="divHeader" class="Header" align="center">
#                         <img src="images/agencyname.gif" id="imgAgencyBanner"><br>
#                         <table width="100%" cellpadding="0" cellspacing="0" border="0">
#                             <tbody><tr>
#                                 <td>
#                                     <table id="classicmenu" width="100%" cellpadding="0" cellspacing="0" border="0">
# 	<tbody><tr style="line-height: 11px; padding: 1px 0 2px 0;">
# 		<td class="Menu p2c-menu-bar">
#                                                 <font size="1" class="MainFont"><strong>
#                                                     <span id="lblMenu">  <a class="MenuText p2c-nowrap" href="./main.aspx">HOME</a><span class="MenuText">&nbsp;&nbsp;&nbsp;&nbsp;</span>  <a class="MenuText p2c-nowrap" href="./summary.aspx">SEARCH REPORTS</a><span class="MenuText">&nbsp;&nbsp;&nbsp;&nbsp;</span>  <a class="MenuText p2c-nowrap" href="./reportincident/incidententryintro.aspx">FILE A NEW REPORT</a><span class="MenuText">&nbsp;&nbsp;&nbsp;&nbsp;</span>  <a class="MenuText p2c-nowrap" href="./communitycalendar.aspx">COMMUNITY CALENDAR</a></span></strong></font>
#                                             </td>
# 		<td class="Menu p2c-menu-bar" align="right">
#                                                 <select name="ctl00$MasterPage$DDLSiteMap1$ddlQuickLinks" onchange="javascript:setTimeout('__doPostBack(\'ctl00$MasterPage$DDLSiteMap1$ddlQuickLinks\',\'\')', 0)" id="DDLSiteMap1_ddlQuickLinks" class="ShadowBoxDark">
# 			<option selected="selected" value="~/0">- Quick Links - </option>
# 			<option value="~/main.aspx">Home</option>
# 			<option value="~/summary.aspx">Search Reports</option>
# 			<option value="~/reportincident/incidententryintro.aspx">File A New Report</option>
# 			<option value="~/communitycalendar.aspx">Community Calendar</option>
# 			<option value="~/mostwanted.aspx">Most Wanted</option>
# 			<option value="~/missing.aspx">Missing Persons</option>
# 			<option value="~/arrests.aspx">Arrests</option>
# 			<option value="~/dailybulletin.aspx">Daily Bulletin</option>
# 			<option value="~/accidentdetail.aspx">Crash Reports</option>
#
# 		</select>
#
#                                             </td>
# 	</tr>
# </tbody></table>
#
#                                 </td>
#                             </tr>
#                             <tr>
#                                 <td class="ui-widget">
#                                     <table id="superfishtb" width="100%" cellpadding="0" cellspacing="0" border="0">
# 	<tbody><tr style="padding: 0 0 0 0;">
# 		<td style="font-size: 1em;" class="ui-widget-header">
#                                                 <!-- Use the Literal control below to store JQuery Menu scripts-->
#
#                                                 <!-- Use the Literal control below to store JQuery Menu scripts-->
#                                             </td>
# 	</tr>
# </tbody></table>
#
#                                 </td>
#                             </tr>
#
#                         </tbody></table>
#                     </div>
#                 </td>
#             </tr>
#             <tr class="p2c-main-content-row">
#                 <td valign="top">
#
#
#     <table cellpadding="0" cellspacing="0" style="width: 100%; height:100%;">
#
#         <tbody><tr>
#             <td class="LeftTable" style="width: 155px;" valign="top" align="center">
#
#                     <div style="padding: 40px 12px 12px 12px;">
#                         <div id="mainContent_LeftColumnContent_PnlLoadUC1" style="margin-bottom: 20px;">
#
# </div>
#                         <div id="mainContent_LeftColumnContent_PnlLoadUC3" style="margin-bottom: 20px;">
#
# </div>
#                         <div id="mainContent_LeftColumnContent_PnlLoadUC4" style="margin-bottom: 20px;">
#
# </div>
#                         <div id="mainContent_LeftColumnContent_PnlLoadUC5" style="margin-bottom: 20px;">
#
# </div>
#                     </div>
#
#             </td>
#             <td style="height: 248px; padding:10px;" valign="top" align="center">
#                 <div class="p2c-border" style="text-align:center;">
#
#
#                     <div style="margin: 1em auto .2em auto; font-style: italic; font-family: Georgia, Arial; font-variant: small-caps; font-weight: bold; text-align: center;" class="MainFont">Please Read</div>
#
#
#     <div id="mainContent_CenterColumnContent_pnlMain" style="width:100%;">
#
#         <table id="Table4" cellspacing="1" cellpadding="1" width="100%" border="0">
#             <tbody><tr>
#                 <td align="center">
#                     <div style="width: 600px; text-align: left; margin: 1em auto 1.5em auto;">
#                         <div id="mainContent_CenterColumnContent_tmceDisclaimer_cv" name="ctl00$MasterPage$mainContent$CenterColumnContent$tmceDisclaimer_cv">
# 		This application is provided as a service to the citizens of our area.  This agency makes no warranty or representation, express or implied, with respect to the quality, content, accuracy, completeness, currency, freedom from computer virus, or non-infringement of proprietary rights, of any of the design, information, text, graphics, images, pages, interfaces, links, software, or other materials and items contained in or displayed on this site.  All such items and materials are provided on an "as is" basis and you are fully and solely responsible for your use of them and for any results or consequences of your use.  <br><br>These materials are subject to change without notice from this agency.<b><i> Commercial use is prohibited without the prior written permission of this agency. </i></b></div>
#                     </div>
#                     <input type="submit" name="ctl00$MasterPage$mainContent$CenterColumnContent$btnContinue" value="I Agree" id="mainContent_CenterColumnContent_btnContinue" autocomplete="off">
#                 </td>
#             </tr>
#         </tbody></table>
#
# 	</div>
#
#
#                         <div id="mainContent_AdminPanel_pnlAdmin" style="width:381px; margin: 0 auto;">
#
# 	</div>
#
#                 </div>
#             </td>
#             <td class="RightTable" style="width: 155px" valign="top" align="center">
#
#                     <div style="padding: 40px 12px 12px 12px;">
#                         <div id="mainContent_RightColumnContent_PnlLoadUC12" style="margin-bottom: 20px;">
#
# 	</div>
#                         <div id="mainContent_RightColumnContent_PnlLoadUC13" style="margin-bottom: 20px;">
#
# 	</div>
#                         <div id="mainContent_RightColumnContent_PnlLoadUC14" style="margin-bottom: 20px;">
#
# 	</div>
#                         <div id="mainContent_RightColumnContent_PnlLoadUC15" style="margin-bottom: 20px;">
#
# 	</div>
#                     </div>
#
#             </td>
#         </tr>
#     </tbody></table>
#
#                     <div id="pnlThemeSwitcher">
#
# 	</div>
#                 </td>
#             </tr>
#             <tr>
#                 <td class="Footer" align="center" style="font-size: 10pt;">
#                     <div style="margin: 2px 0;">
#
#                         <span class="FooterText">powered by</span>
#                         <a href="https://www.superion.com/public-safety/" class="NoUnderLine">
#                             <span style="color: mediumblue;">Superion</span>
#                         </a>
#                         <span class="FooterText">'s P2C engine</span>
#                     </div>
#                 </td>
#             </tr>
#         </tbody></table>
#     <div id="_UniqueWaitControlID" style="visibility:hidden;height:10px;">
# 		<table width="100%" height="100%">
# <tbody><tr><td align="middle">
# <span id="_WaitControlMessageID">Request in process, please wait...</span>
# </td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td align="middle">
# <img id="_UniqueWaitControlID_Image1" src="/images/progress1.gif" align="middle" name="Image1">
# </td></tr>
# <tr><td align="middle"><a style="color:#3333cc;text-decoration:underline;" href="javascript:window.document.fireEvent(&quot;onstop&quot;); void 0;">Cancel</a></td></tr>
# </tbody></table>
#
# 	</div>
# 	<script language="javascript">
# function DetectPopupBlocker()
# {
#   var bPopupBlocker;
#   var newWin = window.open('','','top=5000,left=5000,width=1,height=1,scrollbars=no');
#   if (newWin)
#   {
#     bPopupBlocker = false;
#     newWin.close();
#   }
#   else
#   {
#     bPopupBlocker = true;
#   }
#   return bPopupBlocker;
# }
# if(DetectPopupBlocker()==true)
# {
#   document.forms[0]._popupBlockerExists.value='true';
# }
# else
# {
#   document.forms[0]._popupBlockerExists.value='false';
# }
# </script>
# <script language="javascript">
# var ImgProgress = new Array(4);
# for (var i=0;i<ImgProgress.length;i++)
# {
# ImgProgress[i]=new Image(0,0);
# ImgProgress[i].src = '/images/progress' + (i+1) + '.gif';
# }
# function WaitALittleBit()
# {
# setTimeout('InProcessPleaseWait()',750);
# }
# function InProcessPleaseWait()
# {
# document.forms[0].style.visibility='hidden';
# _UniqueWaitControlID.style.left = (document.body.offsetWidth / 2) - (_UniqueWaitControlID.offsetWidth / 2);
# _UniqueWaitControlID.style.top = (document.body.offsetHeight / 2) - (_UniqueWaitControlID.offsetHeight / 2);
# _UniqueWaitControlID.style.position = 'absolute';
# _UniqueWaitControlID.style.visibility='visible';
# AnimationImage();
# }
# var ImgIndex=0;
# function AnimationImage()
# {
# window.document._UniqueWaitControlID_Image1.src=ImgProgress[ImgIndex%ImgProgress.length].src;
# ImgIndex++;
# if (document.readyState!='complete')
# {
# setTimeout('AnimationImage()',250);
# }
# else
# {
# document.forms[0].style.visibility='visible';
# _UniqueWaitControlID.style.visibility='hidden';
# }
# }
# </script>
#
# <script language="javascript">
# function onsubmitEventsHandler(){
# if(WaitALittleBit()==false){return false;}
# return true;}
# </script></form>
#
#
#
# </body></html>

# %%
'''Click submit on initial page'''
driver.find_element(By.NAME, "ctl00$MasterPage$mainContent$CenterColumnContent$btnContinue").click()

# %%
print(driver.page_source)
# Out:
# <html><head><meta http-equiv="Page-Enter" content="Alpha(opacity=100)"><meta http-equiv="content-type" content="text/html; charset=utf-8"><link id="activeStylesheetLink" href="css/active.css" rel="Stylesheet"><link id="commonStylesheet" href="css/p2cBase.css" rel="Stylesheet"><link rel="Shortcut Icon" href="./images/favicon.ico" type="image/x-icon"><script src="js/jquery-1.8.3.min.js" type="text/javascript"></script><script src="jqui/1.8/jquery-ui-1.8.custom.min.js" type="text/javascript"></script><link href="jqui/1.8/black-tie/jquery-ui.css" rel="Stylesheet" class="ui-theme"><link href="jqui/1.8/black-tie/theme.css" rel="Stylesheet" class="ui-theme">
#     <script type="text/javascript">
#         //window.onload = function() { window.name = "p2c_summary" };
#         window.name = "p2c_summary";
#         function ModifyWaitMessage(link) {
#             if (link.innerHTML.toUpperCase().indexOf('CART') > -1) {
#                 _WaitControlMessageID.innerHTML = '<font size=4>Please Wait</font><br>P2C is verifying that the report you are attempting to purchase is available.';
#             }
#             return true;
#         }
#
#
#         $(document).ready(function () {
#             var dates = $('#mainContent_txtDateFrom2, #mainContent_txtDateTo2').datepicker({
#                 maxDate: new Date(),
#                 onSelect: function (selectedDate) {
#                     var option = this.id == "mainContent_txtDateFrom2" ? "minDate" : "maxDate";
#                     var instance = $(this).data("datepicker");
#                     var date = $.datepicker.parseDate(instance.settings.dateFormat || $.datepicker._defaults.dateFormat, selectedDate, instance.settings);
#                     var now = (new Date());
#                     if (date >= now) {
#                         alert('You must select a date before today.');
#                         date = now - 7;
#                     }
#                     dates.not(this).datepicker("option", option, date);
#                 }
#             });
#             //            addGeoCodingEventHander("geofields2");
#         });
#             //
#         //        //for geocoder service
#         //        var geocoder = null;
#         //        function addGeoCodingEventHander(classname)
#         //        {
#         //            geocoder = new google.maps.Geocoder();
#         //            var geoFields = $("." + classname);//geoFields.eq(0): Street Number; geoFields.eq(1): Street Name; geoFields.eq(2): City; geoFields.eq(3): Search Range;
#         //            geoFields.change(function(){
#         //                handleAddressChanged(classname);
#         //            });
#
#         //            geoFields.eq(0).keydown(function(event) {
#         //              if ( event.which == 32 ) {
#         //                 event.preventDefault();
#         //                 geoFields.eq(1).focus();//change focus to street name field
#         //               }
#         //            });
#         //        }
#         //        function handleAddressChanged(classname)
#         //        {
#         //            var geoFields = $("." + classname);//geoFields.eq(0): Street Number; geoFields.eq(1): Street Name; geoFields.eq(2): City; geoFields.eq(3): Search Range;
#         //            if(geoFields.eq(1).val()=='' || geoFields.eq(2).val()=='' || geoFields.eq(3).val()=='')//need specified an address or range search before we start it
#         //            {
#         //                $("#addresslat").val("");
#         //                $("#addresslng").val("");
#         //            }
#         //            else
#         //            {
#         //                var address = geoFields.eq(0).val() + " " + geoFields.eq(1).val() + ", " + $('option:selected', geoFields.eq(2)).text() + ", ";
#         //                geocoder.geocode({ 'address': address }, function (results, status) {
#         //                    if (status == google.maps.GeocoderStatus.OK) {
#         //                        var location = results[0].geometry.location;
#         //                        $("#addresslat").val(location.lat());
#         //                        $("#addresslng").val(location.lng());
#         //                        //alert(address + " = " + location.lat() + "," + location.lng());
#         //                    } else {
#         //                        //alert("Geocode was not successful for the following reason: " + status);
#         //                        $("#addresslat").val("");
#         //                        $("#addresslng").val("");
#         //                    }
#         //                });
#         //            }
#         //        }
#         //        function markAddress() {
#         //            if ($("#txtStreetName").val() == "") {
#         //                setCenter(map.getCenter(), $("#selRange").val());
#         //            } else {
#         //                var address = $("#txtStreetNumber").val() + " " + $("#txtStreetName").val() + " " + $("#txtCity").val() + " " + $("#txtState").val()
#         //                geocoder.geocode({ 'address': address }, function (results, status) {
#         //                    if (status == google.maps.GeocoderStatus.OK) {
#         //                        setCenter(results[0].geometry.location, $("#selRange").val()); //if we have range value is string and could be ""
#         //                    } else {
#         //                        alert("Geocode was not successful for the following reason: " + status);
#         //                    }
#         //                });
#         //            }
#         //        }
#     </script>
#     <style type="text/css">
#         .hoverCartLink {
#             text-decoration: none;
#         }
#
#             .hoverCartLink:hover {
#                 text-decoration: underline;
#             }
#
#         .EventSearchGridHeader {
#             text-align: left;
#             background: #777;
#             font-size: .95em;
#         }
#
#             .EventSearchGridHeader :hover {
#                 background: #000;
#             }
#
#             .EventSearchGridHeader a:hover {
#                 color: #ffa;
#                 font-weight: bold;
#                 text-decoration: none;
#             }
#
#             .EventSearchGridHeader a {
#                 color: #fff;
#                 text-decoration: none;
#                 display: block;
#                 padding: 0 2px 2px 2px;
#             }
#
#         .EventSearchGridRow {
#             color: #000;
#             font-size: 9pt;
#             padding: 0 2px;
#         }
#
#         .ui-widget-content {
#             padding: .5em;
#             margin-bottom: .5em;
#         }
#
#             .ui-widget-content .ui-widget-header {
#                 font-size: .8em;
#             }
#     </style>
# <link id="jquiOverride" href="css/jqui-override.css" rel="Stylesheet">
#     <script language="javascript" type="text/javascript">
#         // DO NOT REMOVE
#         // this function is used by the form builder
#         // to control tab index issues
#         function getASPElm(nm, tag) {
#             if ($get(nm)) { return $get(nm); }
#             if (!tag) { tag = '*'; }
#             var e = document.getElementsByTagName(tag);
#             for (var i = 0; i < e.length; i++) {
#                 if (e[i].id) {
#                     if (e[i].id.indexOf(nm) != -1) {
#                         return e[i];
#                     }
#                 }
#             }
#             return null;
#         }
#
#         $(document).ready(function () {
#             $("input").attr("autocomplete", "off");
#         });
#     </script>
#
#     <!-- JQuery Menu Helper Script -->
#
#     <!-- JQuery Menu Helper Script -->
# <title>
# 	Wilmington Police Department P2C
# </title></head>
#
# <body class="Body">
#     <script language="javascript" type="text/javascript">
#         $(function () {
#             var backgrounds = [
#
#             ];
#
#             var path = '';
#             var $body = $(document.body);
#             backgrounds.forEach(function (background, index) {
#                 var $element = $('<div class="background-image toggle-image' + (index === 0 ? ' show' : '') + '" style="background-image: url(\''+ path + '/images/background/' + background + '\'); z-index: -' + index + 1 + ';" ></div>');
#                 $body.append($element);
#             });
#
#             (function () {
#                 if (backgrounds.length > 1) {
#                     var index = 0;
#
#                     $imageElements = $('.toggle-image'); // Get the images to be cycled.
#
#                     setInterval(function () {
#                         index = index + 1 < $imageElements.length ? index + 1 : 0;
#                         $imageElements.eq(index - 1).removeClass('show');
#                         $imageElements.eq(index).addClass('show');
#                     }, 18000);
#                 }
#             })();
#         });
#     </script>
#     <form method="post" action="./Summary.aspx" onkeypress="javascript:return WebForm_FireDefaultButton(event, 'mainContent_cmdSubmit2')" id="Form1" onsubmit="return(onsubmitEventsHandler());">
# <div class="aspNetHidden">
# <input type="hidden" name="__LASTFOCUS" id="__LASTFOCUS" value="" autocomplete="off">
# <input type="hidden" name="__EVENTTARGET" id="__EVENTTARGET" value="" autocomplete="off">
# <input type="hidden" name="__EVENTARGUMENT" id="__EVENTARGUMENT" value="" autocomplete="off">
# <input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." autocomplete="off">
# </div>
#
# <script type="text/javascript">
# //<![CDATA[
# var theForm = document.forms['Form1'];
# if (!theForm) {
#     theForm = document.Form1;
# }
# function __doPostBack(eventTarget, eventArgument) {
#     if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
#         theForm.__EVENTTARGET.value = eventTarget;
#         theForm.__EVENTARGUMENT.value = eventArgument;
#         theForm.submit();
#     }
# }
# //]]>
# </script>
#
#
# <script src="/WebResource.axd?d=vclQug-sKxnxODmCeXGQIlawbQqKkc_GESu3RpAb4gaZzsTLp7OO3OQAA70g6_FFExzRr_3eZJJoVdSpkhRbS-9KU1Obd_uAqYxOBqCG8gc1&amp;t=637045004158587729" type="text/javascript"></script>
#
#
# <script src="/WebResource.axd?d=u1QJOgatDp2PYSLjIiCkiCM126_cwQLqNiDVpADgqBNDPoKdHaRT7sM3coxeq4jG7FEDTJgKT_ICRVwzliXMznHpgTQ801vexp_7-ZESl581&amp;t=637045004158587729" type="text/javascript"></script>
# <div class="aspNetHidden">
#
# 	<input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="BCFEF455" autocomplete="off">
# 	<input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="..." autocomplete="off">
# </div>
#
#
#         <table class="MainTable" id="Table1" cellspacing="0" cellpadding="0">
#             <tbody><tr height="40px">
#                 <td valign="bottom" align="left">
#                     <div id="divHeader" class="Header" align="center">
#                         <img src="images/agencyname.gif" id="imgAgencyBanner"><br>
#                         <table width="100%" cellpadding="0" cellspacing="0" border="0">
#                             <tbody><tr>
#                                 <td>
#                                     <table id="classicmenu" width="100%" cellpadding="0" cellspacing="0" border="0">
# 	<tbody><tr style="line-height: 11px; padding: 1px 0 2px 0;">
# 		<td class="Menu p2c-menu-bar">
#                                                 <font size="1" class="MainFont"><strong>
#                                                     <span id="lblMenu">  <a class="MenuText p2c-nowrap" href="./main.aspx">HOME</a><span class="MenuText">&nbsp;&nbsp;&nbsp;&nbsp;</span>  <a class="MenuText p2c-nowrap" href="./summary.aspx">SEARCH REPORTS</a><span class="MenuText">&nbsp;&nbsp;&nbsp;&nbsp;</span>  <a class="MenuText p2c-nowrap" href="./reportincident/incidententryintro.aspx">FILE A NEW REPORT</a><span class="MenuText">&nbsp;&nbsp;&nbsp;&nbsp;</span>  <a class="MenuText p2c-nowrap" href="./communitycalendar.aspx">COMMUNITY CALENDAR</a></span></strong></font>
#                                             </td>
# 		<td class="Menu p2c-menu-bar" align="right">
#                                                 <select name="MasterPage$DDLSiteMap1$ddlQuickLinks" onchange="javascript:setTimeout('__doPostBack(\'MasterPage$DDLSiteMap1$ddlQuickLinks\',\'\')', 0)" id="DDLSiteMap1_ddlQuickLinks" class="ShadowBoxDark">
# 			<option selected="selected" value="~/0">- Quick Links - </option>
# 			<option value="~/main.aspx">Home</option>
# 			<option value="~/summary.aspx">Search Reports</option>
# 			<option value="~/reportincident/incidententryintro.aspx">File A New Report</option>
# 			<option value="~/communitycalendar.aspx">Community Calendar</option>
# 			<option value="~/mostwanted.aspx">Most Wanted</option>
# 			<option value="~/missing.aspx">Missing Persons</option>
# 			<option value="~/arrests.aspx">Arrests</option>
# 			<option value="~/dailybulletin.aspx">Daily Bulletin</option>
# 			<option value="~/accidentdetail.aspx">Crash Reports</option>
#
# 		</select>
#
#                                             </td>
# 	</tr>
# </tbody></table>
#
#                                 </td>
#                             </tr>
#                             <tr>
#                                 <td class="ui-widget">
#                                     <table id="superfishtb" width="100%" cellpadding="0" cellspacing="0" border="0">
# 	<tbody><tr style="padding: 0 0 0 0;">
# 		<td style="font-size: 1em;" class="ui-widget-header">
#                                                 <!-- Use the Literal control below to store JQuery Menu scripts-->
#
#                                                 <!-- Use the Literal control below to store JQuery Menu scripts-->
#                                             </td>
# 	</tr>
# </tbody></table>
#
#                                 </td>
#                             </tr>
#
#                         </tbody></table>
#                     </div>
#                 </td>
#             </tr>
#             <tr class="p2c-main-content-row">
#                 <td valign="top">
#
#                         <div class="p2c-page-title">
#
#                         </div>
#
#
#     <div class="p2c-border p2c-user-border p2c-user-margin">
#
#         <table id="Table9" cellspacing="0" cellpadding="0" border="0">
#
#             <tbody><tr>
#                 <td align="center">
#                     <div class="ui-widget" style="width: 681px; margin: 0 auto .3em auto;">
#                         <div class="ui-widget-header">Event Search</div>
#                         <div class="ui-widget-content" style="padding: 0;">
#                             <table cellpadding="4" cellspacing="0" border="0" style="text-align: center;">
#                                 <tbody><tr>
#                                     <td colspan="2">
#                                         <div class="ui-widget">
#                                             <div class="ui-widget-header">What?</div>
#                                             <div class="ui-widget-content" style="padding: .2em; margin: 0;">
#                                                 <table class="ui-widget-content noPad" cellspacing="0" cellpadding="0" border="0" style="width: 90%; font-size: .8em; background: inherit; border: 0; margin: 0;">
#                                                     <tbody><tr>
#                                                         <td id="mainContent_tdAccidentPin2" style="width: 5%; text-align: right; padding-right: .5em;">
#                                                             <img src="images/PinAccident.png" alt="">
#                                                         </td>
#
#                                                         <td id="mainContent_tdAccidentCheckbox2" style="width: 20%;">
#                                                             <input id="mainContent_chkTA2" type="checkbox" name="MasterPage$mainContent$chkTA2" checked="checked" autocomplete="off">Accidents
#                                                         </td>
#
#                                                         <td id="mainContent_tdArrestPin2" style="width: 5%; text-align: right; padding-right: .5em;">
#                                                             <img src="images/PinArrest.png" alt="">
#                                                         </td>
#
#                                                         <td id="mainContent_tdArrestCheckbox2" style="width: 20%;">
#                                                             <input id="mainContent_chkAR2" type="checkbox" name="MasterPage$mainContent$chkAR2" checked="checked" autocomplete="off">
#                                                             Arrests
#                                                         </td>
#
#                                                         <td id="mainContent_tdIncidentPin2" style="width: 5%; text-align: right; padding-right: .5em;">
#                                                             <img src="images/PinIncident.png" alt="">
#                                                         </td>
#
#                                                         <td id="mainContent_tdIncidentCheckbox2" style="width: 20%;">
#                                                             <input id="mainContent_chkLW2" type="checkbox" name="MasterPage$mainContent$chkLW2" checked="checked" autocomplete="off">
#                                                             Incidents
#                                                         </td>
#
#
#
#                                                     </tr>
#                                                     <tr>
#                                                         <th colspan="4" align="right" style="padding-right: .5em;">Case #:</th>
#                                                         <td align="left" colspan="4">
#                                                             <input name="MasterPage$mainContent$txtCase2" type="text" maxlength="75" id="mainContent_txtCase2" onchange="if(ValidateInteger(this)==false) return false;" style="width:106px;" autocomplete="off">
#                                                         </td>
#                                                     </tr>
#                                                 </tbody></table>
#                                             </div>
#                                         </div>
#                                     </td>
#                                 </tr>
#                                 <tr valign="top">
#                                     <td style="width: 50%;">
#                                         <div class="ui-widget">
#                                             <div class="ui-widget-header">When?</div>
#                                             <div class="ui-widget-content" style="height: 4em; padding: .2em; margin: 0;">
#                                                 <table class="ui-widget-content noPad" cellspacing="0" cellpadding="0" border="0" style="font-size: .8em; background: inherit; border: 0; margin: 0; width: 100%;">
#                                                     <tbody><tr>
#                                                         <td colspan="3">Search By:
#                                                         <span id="mainContent_rblSearchDateToUse2"><input id="mainContent_rblSearchDateToUse2_0" type="radio" name="MasterPage$mainContent$rblSearchDateToUse2" value="Date Occurred" checked="checked" autocomplete="off"><label for="mainContent_rblSearchDateToUse2_0">Date Occurred</label><input id="mainContent_rblSearchDateToUse2_1" type="radio" name="MasterPage$mainContent$rblSearchDateToUse2" value="Date Reported" autocomplete="off"><label for="mainContent_rblSearchDateToUse2_1">Date Reported</label></span><br>
#                                                         </td>
#                                                     </tr>
#                                                     <tr align="left">
#                                                         <th>Date:
#                                                         </th>
#                                                         <th>From: <span style="color: #f00">*</span>
#                                                         </th>
#                                                         <th>To: <span style="color: #f00">*</span>
#                                                         </th>
#                                                     </tr>
#                                                     <tr>
#                                                         <td>
#                                                             <select name="MasterPage$mainContent$ddlDates2" onchange="javascript:setTimeout('__doPostBack(\'MasterPage$mainContent$ddlDates2\',\'\')', 0)" id="mainContent_ddlDates2">
# 	<option value="This Week">This Week</option>
# 	<option value="Last Week">Last Week</option>
# 	<option value="This Month">This Month</option>
# 	<option value="Last Month">Last Month</option>
# 	<option selected="selected" value="Specify Date">Specify Date</option>
#
# </select>
#                                                         </td>
#                                                         <td>
#                                                             <input name="MasterPage$mainContent$txtDateFrom2" type="text" value="9/20/2022" id="mainContent_txtDateFrom2" style="width:85px;" class="hasDatepicker" autocomplete="off">
#
#                                                         </td>
#                                                         <td>
#                                                             <input name="MasterPage$mainContent$txtDateTo2" type="text" value="9/21/2022" id="mainContent_txtDateTo2" style="width:85px;" class="hasDatepicker" autocomplete="off">
#
#                                                         </td>
#                                                     </tr>
#                                                 </tbody></table>
#                                             </div>
#                                         </div>
#                                     </td>
#                                     <td>
#                                         <div class="ui-widget">
#                                             <div class="ui-widget-header">Who?</div>
#                                             <div class="ui-widget-content" style="height: 4em; padding: .2em; margin: 0;">
#                                                 <table class="ui-widget-content noPad" cellspacing="0" cellpadding="0" border="0" style="font-size: .8em; background: inherit; border: none; margin: 0; width: 100%;">
#                                                     <tbody><tr valign="bottom" align="left">
#                                                         <th>Last Name / Business:
#                                                         </th>
#                                                         <th>First Name:
#                                                         </th>
#                                                         <th>Middle Name:
#                                                         </th>
#                                                     </tr>
#                                                     <tr>
#                                                         <td style="width: 33.3%;">
#                                                             <input name="MasterPage$mainContent$txtLName2" type="text" maxlength="75" id="mainContent_txtLName2" style="width:98%;" autocomplete="off">
#                                                         </td>
#                                                         <td style="width: 33.3%;">
#                                                             <input name="MasterPage$mainContent$txtFName2" type="text" maxlength="75" id="mainContent_txtFName2" style="width:98%;" autocomplete="off">
#                                                         </td>
#                                                         <td>
#                                                             <input name="MasterPage$mainContent$txtMName2" type="text" maxlength="75" id="mainContent_txtMName2" style="width:98%;" autocomplete="off">
#                                                         </td>
#                                                     </tr>
#                                                 </tbody></table>
#                                             </div>
#                                         </div>
#                                     </td>
#                                 </tr>
#                                 <tr>
#                                     <td colspan="2">
#                                         <div class="ui-widget">
#                                             <div class="ui-widget-header">Where?</div>
#                                             <div class="ui-widget-content" style="padding: .2em; margin: 0;">
#                                                 <table class="ui-widget-content noPad" cellspacing="3" cellpadding="0" border="0" style="width: 90%; font-size: .8em; background: inherit; border: 0; margin: 0;">
#                                                     <tbody><tr align="left">
#                                                         <th style="width: 33.3%;">Street #:
#                                                         </th>
#                                                         <th style="width: 33.3%;">Street Name:
#                                                         </th>
#                                                         <th>City:
#                                                         </th>
#                                                     </tr>
#                                                     <tr>
#                                                         <td>
#                                                             <input name="MasterPage$mainContent$txtStreetNo2" type="text" maxlength="75" id="mainContent_txtStreetNo2" class="geofields2" style="width:100%;" autocomplete="off">
#                                                         </td>
#                                                         <td>
#                                                             <input name="MasterPage$mainContent$txtStreetName2" type="text" maxlength="75" id="mainContent_txtStreetName2" class="geofields2" style="width:100%;TEXT-TRANSFORM:uppercase;" autocomplete="off">
#                                                         </td>
#                                                         <td>
#
#                                                             <select name="MasterPage$mainContent$CGeoCityDDL12" id="mainContent_CGeoCityDDL12" class="geofields2" style="width:100%;">
# 	<option selected="selected" value=""></option>
# 	<option value="CB">CAROLINA BEACH</option>
# 	<option value="CH">CASTLE HAYNE</option>
# 	<option value="KB">KURE BEACH</option>
# 	<option value="WM">WILMINGTON</option>
# 	<option value="NHC">WILMINGTON1</option>
# 	<option value="UNK">WILMINGTON2</option>
# 	<option value="WIL">WILMINGTON3</option>
# 	<option value="WB">WRIGHTSVILLE BEACH</option>
#
# </select>
#                                                         </td>
#                                                     </tr>
#                                                     <tr align="left">
#                                                         <th colspan="2">
#
#                                                         </th>
#                                                         <th>
#                                                             <div id="mainContent_lblRangeSearch2">Search Range:</div>
#                                                         </th>
#                                                     </tr>
#                                                     <tr valign="top">
#                                                         <td colspan="2">
#
#                                                         </td>
#                                                         <td>
#                                                             <select name="MasterPage$mainContent$ddlRange2" id="mainContent_ddlRange2" class="geofields2" style="width:100%;">
# 	<option value=""></option>
# 	<option value="0.094697">500 feet</option>
# 	<option value="0.189394">1000 feet</option>
# 	<option value="0.284091">1500 feet</option>
# 	<option value="0.378788">2000 feet</option>
# 	<option value="0.5">0.5 mile</option>
# 	<option value="1.0">1.0 mile</option>
# 	<option value="1.5">1.5 miles</option>
# 	<option value="2.0">2.0 miles</option>
# 	<option value="5.0">5.0 miles</option>
# 	<option value="10.0">10.0 miles</option>
# 	<option value="15.0">15.0 miles</option>
# 	<option value="20.0">20.0 miles</option>
#
# </select>
#                                                         </td>
#                                                     </tr>
#                                                 </tbody></table>
#                                             </div>
#                                         </div>
#                                     </td>
#                                 </tr>
#                                 <tr>
#                                     <td colspan="2" style="text-align: center;">
#                                         <a onclick="_WaitControlMessageID.innerHTML='Request in process, please wait...';" id="mainContent_cmdSubmit2" title="Run an Event Search with the displayed criteria" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-icon ui-state-hover ui-state-focus" href="javascript:__doPostBack('MasterPage$mainContent$cmdSubmit2','')" style="margin: 0 auto; font-size: .8em;"><span class="ui-button-icon-primary ui-icon ui-icon-search"></span><span class="ui-button-text">Search</span></a>
#                                         <a id="mainContent_btnReset2" title="Remove the values entered from this form" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-icon ui-state-hover ui-state-focus" href="javascript:__doPostBack('MasterPage$mainContent$btnReset2','')" style="margin: 0 auto; font-size: .8em;"><span class="ui-button-icon-primary ui-icon ui-icon-arrowreturnthick-1-w"></span><span class="ui-button-text">Reset</span></a>
#                                     </td>
#                                 </tr>
#                             </tbody></table>
#                         </div>
#                     </div>
#                 </td>
#             </tr>
#
#             <tr>
#                 <td align="center">
#                     <table id="tblFooter" cellspacing="0" cellpadding="0" width="100%" align="center" border="0">
#                         <tbody><tr>
#                             <td align="center" colspan="3">
#
#                             </td>
#                         </tr>
#                         <tr>
#                             <td align="center" colspan="3">
#                                 <span id="mainContent_lblSearch" class="MainFont" style="display:inline-block;width:552px;"> <br> Please  click "Search" to execute a search when you have completed entering search criteria</span>
#                             </td>
#                         </tr>
#                         <tr>
#                             <td align="center" colspan="3">
#
#                             </td>
#                         </tr>
#                         <tr>
#                             <td align="center" colspan="3">
#                                 <div>
#
# </div>
#                             </td>
#                         </tr>
#                         <tr>
#                             <td valign="middle" align="center" colspan="3">
#                                 <table id="Table6" cellspacing="1" cellpadding="1" width="682" border="0">
#                                     <tbody><tr>
#                                         <td>
#
#                                         </td>
#                                         <td align="right">
#
#                                         </td>
#                                     </tr>
#                                 </tbody></table>
#
#                             </td>
#                         </tr>
#                         <tr>
#                             <td class="footerText" style="height: 12px" align="center" colspan="3">
#                                 <font size="2"></font>
#                             </td>
#                         </tr>
#                         <tr>
#                             <td class="footerText" style="height: 15px" align="center" colspan="3"></td>
#                         </tr>
#                     </tbody></table>
#                 </td>
#             </tr>
#         </tbody></table>
#         <input name="MasterPage$mainContent$addresslat" type="hidden" id="mainContent_addresslat" autocomplete="off">
#         <input name="MasterPage$mainContent$addresslng" type="hidden" id="mainContent_addresslng" autocomplete="off">
#         <iframe id="mainContent_MapiFrame" style="z-index: 101; left: 0px; width: 0px; position: absolute; top: 0px; height: 0px; background-color: transparent" marginwidth="0" marginheight="0" frameborder="0"></iframe>
#     </div>
#
#                     <div id="pnlThemeSwitcher">
#
# </div>
#                 </td>
#             </tr>
#             <tr>
#                 <td class="Footer" align="center" style="font-size: 10pt;">
#                     <div style="margin: 2px 0;">
#
#                         <span class="FooterText">powered by</span>
#                         <a href="https://www.superion.com/public-safety/" class="NoUnderLine">
#                             <span style="color: mediumblue;">Superion</span>
#                         </a>
#                         <span class="FooterText">'s P2C engine</span>
#                     </div>
#                 </td>
#             </tr>
#         </tbody></table>
#     <div id="_UniqueWaitControlID" style="visibility:hidden;height:10px;">
# 	<table width="100%" height="100%">
# <tbody><tr><td align="middle">
# <span id="_WaitControlMessageID"><font size="4">Please Wait</font><br>Your report is being generated<br><font size="2" color="gray">(You must have Adobe Acrobat installed and any popup blockers disabled to view a report.)</font></span>
# </td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td align="middle">
# <img id="_UniqueWaitControlID_Image1" src="images/waitwindow_1.gif" align="middle" name="Image1">
# </td></tr>
# <tr><td align="middle"><a style="color:#3333cc;text-decoration:underline;" href="javascript:window.document.fireEvent(&quot;onstop&quot;); void 0;">Cancel</a></td></tr>
# </tbody></table>
#
# </div>
# <script language="javascript">
# function ValidateInteger(Element)
# {
#    if (Element==null) return null;
#     if(Element.value!='' && Element.className!='watermark')
#     {
#         var re =/^\d*[%*]?$/;
#         if (re.test(Element.value) == true)
#         {
# 	          return true;
# 	       }
#         else
#         {
#            (event)?event.returnValue=false:'';
#            alert('Invalid Integer. Please enter a number without decimal point.');
#            Element.select();
#            Element.focus();
#            return false;
#         }
#     }else{
#       return true;
#     }
# }
# </script>
# <script language="javascript">
# var ImgProgress = new Array(8);
# for (var i=0;i<ImgProgress.length;i++)
# {
# ImgProgress[i]=new Image(0,0);
# ImgProgress[i].src = 'images/waitwindow_' + (i+1) + '.gif';
# }
# function WaitALittleBit()
# {
# setTimeout('InProcessPleaseWait()',300);
# }
# function InProcessPleaseWait()
# {
# document.forms[0].style.visibility='hidden';
# _UniqueWaitControlID.style.left = (document.body.offsetWidth / 2) - (_UniqueWaitControlID.offsetWidth / 2);
# _UniqueWaitControlID.style.top = (document.body.offsetHeight / 2) - (_UniqueWaitControlID.offsetHeight / 2);
# _UniqueWaitControlID.style.position = 'absolute';
# _UniqueWaitControlID.style.visibility='visible';
# AnimationImage();
# }
# var ImgIndex=0;
# function AnimationImage()
# {
# window.document._UniqueWaitControlID_Image1.src=ImgProgress[ImgIndex%ImgProgress.length].src;
# ImgIndex++;
# if (document.readyState!='complete')
# {
# setTimeout('AnimationImage()',250);
# }
# else
# {
# document.forms[0].style.visibility='visible';
# _UniqueWaitControlID.style.visibility='hidden';
# }
# }
# </script>
#
# <script language="javascript">
# function onsubmitEventsHandler(){
# if(ValidateInteger(window.document.forms[0].mainContent_txtCase)==false){return false;}
# if(ValidateInteger(window.document.forms[0].mainContent_txtCase2)==false){return false;}
# if(WaitALittleBit()==false){return false;}
# return true;}
# </script>
# <script type="text/javascript">
# //<![CDATA[
# WebForm_AutoFocus('mainContent_txtLName2');//]]>
# </script>
# </form>
#
#
#
# <div id="ui-datepicker-div" class="ui-datepicker ui-widget ui-widget-content ui-helper-clearfix ui-corner-all ui-helper-hidden-accessible"></div></body></html>

# %%
'''Complete form fields'''
driver.find_element(By.NAME, "MasterPage$mainContent$txtDateFrom2").clear()
driver.find_element(By.NAME, "MasterPage$mainContent$txtDateFrom2").send_keys('9/25/2021')

driver.find_element(By.ID, "mainContent_chkTA2").click()

try: 
    driver.find_element(By.NAME, "MasterPage$mainContent$CGeoCityDDL12").clear()
except:
    pass
driver.find_element(By.NAME, "MasterPage$mainContent$CGeoCityDDL12").send_keys('WILMINGTON')

try:
    driver.find_element(By.NAME, "MasterPage$mainContent$ddlRange2").clear()
except:
    pass
driver.find_element(By.NAME, "MasterPage$mainContent$ddlRange2").send_keys('1000')

try:
    driver.find_element(By.NAME, "MasterPage$mainContent$txtStreetNo2").clear()
except:
    pass
driver.find_element(By.NAME, "MasterPage$mainContent$txtStreetNo2").send_keys('105')

try:
    driver.find_element(By.NAME, "MasterPage$mainContent$txtStreetName2").clear()
except:
    pass
driver.find_element(By.NAME, "MasterPage$mainContent$txtStreetName2").send_keys('N 13TH ST')

# %%
'''Submit form via javascript'''
submit =  driver.find_element(By.ID, "mainContent_cmdSubmit2")
driver.execute_script("arguments[0].click()", submit)

# %%
'''Take screenshot of the browser'''
try:
    driver.save_screenshot('screenshot.png')
except:
    pass

# %%
'''data_rows = driver.find_elements(By.XPATH, ('//table[@class="DataGridText"]//tr[@class = "EventSearchGridRow"]//td[position() = 4]'))

for i in data_rows:
    if re.search(r"Primary Offense:(.*)", i.text):
        offense = re.search(r"Primary Offense:(.*)", i.text)
        print(offense.group(1))'''

# %%
'''Save each PDF file to pdf directory'''
#Get number of pages in results table and place it into a list - this is not the total, but the number of pages currently listed
number_current_pages = driver.find_elements(By.XPATH, ('//table[@class="DataGridText"]//tr[@align = "center"]//td//table'))[0].text.split(' ')

#Get overall total number of pages
number_total_pages = driver.find_elements(By.XPATH, ('//span[@id="mainContent_lblRecordCount"]'))[0].text
number_total_pages = re.search(r"\d+", number_total_pages)
number_total_pages = (math.ceil((int(number_total_pages.group(0))/9)))
#print(number_total_pages)

#Create empty list into which to place items as they are extracted
crime_list = []
injury_list = []
relationship_list = []
report_type_list = []
block_list = []
address_list = []
date_list = []

#Cycle through each page in list
current_page = 1
cum_page_count = 0

for page in range(len(number_current_pages)):
    #Extract report type, date and address from results table
    report_type = driver.find_elements(By.XPATH, ('//table[@class="DataGridText"]//tr[@class = "EventSearchGridRow"]//td[position() = 3]'))   

    #Cycle through each document on the page
    for index in range(len(report_type)):
        found_crimes = 0
        found_injuries = 0
        found_relationships = 0
        found_addresses = 0
        
        #Create pdfReader objects out of each file
        if cum_page_count % 9 == 0 & cum_page_count != 0:
            pdf_file_link = driver.find_element(By.ID, f"mainContent_gvSummary_lbGetReport_{index - 1}")
            #print("-1:",index)
        else:
            pdf_file_link = driver.find_element(By.ID, f"mainContent_gvSummary_lbGetReport_{index}")
            #print("-1:",index)
            
        print(f"mainContent_gvSummary_lbGetReport_{index}")
        pdf_file_link.click()
        time.sleep(5)
        os.rename(download_directory+r"\PoliceReport.pdf", download_directory+fr"\PoliceReport{index}.pdf")
        time.sleep(3)
        
        # Within each page, cycle through each line of the data table and extract information
        report_type = driver.find_elements(By.XPATH, ('//table[@class="DataGridText"]//tr[@class = "EventSearchGridRow"]//td[position() = 3]'))
        dates = driver.find_elements(By.XPATH, ('//table[@class="DataGridText"]//tr[@class = "EventSearchGridRow"]//td[position() = 2]'))
        blocks = driver.find_elements(By.XPATH, ('//table[@class="DataGridText"]//tr[@class = "EventSearchGridRow"]//td[position() = 5]'))

        if report_type[index].text == "Incident":
            report_type_list.append(report_type[index].text)
            #print(report_type[index].text)
            date_list.append(dates[index].text)
            #print(dates[index].text)
            block_list.append(blocks[index].text)
            #print(blocks[index].text)
                  
            with open(fr"pdf_files/PoliceReport{index}.pdf", 'rb') as f:
                pdfReader = pypdf(f, "rb")


                #create list of text from page
                page_object = pdfReader.getPage(0)
                page_text = page_object.extractText()
                page = page_text.split("\n")
                address_list_temp = []
                for i in page:
                    found_crimes_loop = 0
                    if page.index(i) == 34:
                        crime_list.append(i)
                        found_crimes_loop += 1
                        found_crimes = found_crimes_loop
                        #print(found_crimes)

                    injury = re.search(r"\d+/\d+/\d{4}(.*)com", i, re.IGNORECASE)
                    found_injuries_loop = 0
                    if injury == '':
                        #print('blank injury')
                        injury_list.append('None')
                        found_injuries_loop += 1
                        found_injuries = found_injuries_loop
                    elif injury is not None:
                        #print('none injury')
                        injury_list.append(injury.group(1))
                        found_injuries_loop += 1
                        found_injuries = found_injuries_loop
                                            

                    relationship = re.search(r"(\d[A-Z]{2})$", i)
                    found_relationships_loop = 0
                    if relationship is not None:
                        relationship_list.append(relationship.group(1))
                        found_relationships_loop += 1
                        found_relationships = found_relationships_loop
                        print(relationship.group(1))
                        
                    address = re.search(r"\d+ (.*) (Wilmington|WM)", i)
                    found_addresses_loop = 0
                
                    if address is not None:
                        print(address.group(0).split(',')[0])
                        address_list_temp.append(address.group(0).split(',')[0][5:])
                        print(address_list_temp)
                        found_addresses_loop += 1
                        found_addresses = found_addresses_loop
                if len(address_list_temp) > 0:
                    address_list.append(address_list_temp[0])
                print(address_list)

                #If any item was not present, append list with None
                if found_injuries == 0:
                    injury_list.append('None')
                if found_crimes == 0:
                    crime_list.append('None')
                #print('found_crimes_end', found_crimes)
                if found_relationships == 0:
                    relationship_list.append('None')
                if found_addresses == 0:
                    address_list.append('None')
                print('crime_list', len(crime_list), crime_list)
                print('injury list', len(injury_list), injury_list)
                print('relationship_list', len(relationship_list), relationship_list)
                print('address_list', len(address_list), address_list)
                print('report_type_list', len(report_type_list), report_type_list)
                print('block_list', len(block_list), block_list)
                print('address_list', len(address_list), address_list)
                print('date_list', len(date_list), date_list)

        cum_page_count += 1
    current_page += 1
    print(current_page)
    new_page = driver.find_element(By.XPATH, f'//a[@href = "javascript:__doPostBack(\'MasterPage$mainContent$gvSummary\',\'Page${current_page}\')"]')
    print(new_page.text)
    driver.execute_script("arguments[0].click()", new_page)
    driver.save_screenshot('screenshot.png')
    number_current_pages = driver.find_elements(By.XPATH, ('//table[@class="DataGridText"]//tr[@align = "center"]//td//table'))[0].text.split(' ')
    #Remove saved files from previous page iteration
    files = os.listdir(download_directory)
    filtered_files = [file for file in files if file.endswith(".pdf")]
    for file in filtered_files:
        path_to_file = os.path.join(download_directory, file)
        os.remove(path_to_file)
print('crime_list', crime_list)
print('injury list', injury_list)
print('relationship_list', relationship_list)
print('address_list',address_list)
print('report_type_list', report_type_list)
print('block_list', block_list)
print('address_list', address_list)
print('date_list', date_list)
# Out:
# mainContent_gvSummary_lbGetReport_0
# 2022 1100 Market St
# ['1100 Market St']
# 615 Bess St  Wilmington
# ['1100 Market St', 'ess St  Wilmington']
# ['1100 Market St']
# crime_list 1 ['Dwi - Alcohol']
# injury list 1 ['']
# relationship_list 1 ['None']
# address_list 1 ['1100 Market St']
# report_type_list 1 ['Incident']
# block_list 1 ['1100-BLK MARKET ST']
# address_list 1 ['1100 Market St']
# date_list 1 ['01/02/2022 01:20']
# mainContent_gvSummary_lbGetReport_1
# 2022 107 N 12th St
# ['107 N 12th St']
# 1110 S 8th St  Wilmington
# ['107 N 12th St', 'S 8th St  Wilmington']
# 107 N 12TH ST  - UP
# ['107 N 12th St', 'S 8th St  Wilmington', ' 12TH ST  - UP']
# ['1100 Market St', '107 N 12th St']
# crime_list 2 ['Dwi - Alcohol', 'Death Investigation']
# injury list 2 ['', '']
# relationship_list 2 ['None', 'None']
# address_list 2 ['1100 Market St', '107 N 12th St']
# report_type_list 2 ['Incident', 'Incident']
# block_list 2 ['1100-BLK MARKET ST', '100-BLK N 12TH ST']
# address_list 2 ['1100 Market St', '107 N 12th St']
# date_list 2 ['01/02/2022 01:20', '01/09/2022 21:03']
# mainContent_gvSummary_lbGetReport_2
# 2022 202 N 13th St
# ['202 N 13th St']
# 202 N 13TH ST
# ['202 N 13th St', ' 13TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St']
# crime_list 3 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)']
# injury list 3 ['', '', '']
# relationship_list 3 ['None', 'None', 'None']
# address_list 3 ['1100 Market St', '107 N 12th St', '202 N 13th St']
# report_type_list 3 ['Incident', 'Incident', 'Incident']
# block_list 3 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST']
# address_list 3 ['1100 Market St', '107 N 12th St', '202 N 13th St']
# date_list 3 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00']
# mainContent_gvSummary_lbGetReport_3
# 2022 1109 Grace St
# ['1109 Grace St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St']
# crime_list 4 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony']
# injury list 4 ['', '', '', '']
# relationship_list 4 ['None', 'None', 'None', 'None']
# address_list 4 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St']
# report_type_list 4 ['Incident', 'Incident', 'Incident', 'Incident']
# block_list 4 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST']
# address_list 4 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St']
# date_list 4 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00']
# mainContent_gvSummary_lbGetReport_4
# 2022 204 N 13th St
# ['204 N 13th St']
# 401 S 15TH ST
# ['204 N 13th St', ' 15TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St']
# crime_list 5 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft']
# injury list 5 ['', '', '', '', '']
# relationship_list 5 ['None', 'None', 'None', 'None', 'None']
# address_list 5 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St']
# report_type_list 5 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 5 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST']
# address_list 5 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St']
# date_list 5 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30']
# mainContent_gvSummary_lbGetReport_5
# 2022 101 N 15th St
# ['101 N 15th St']
# 101 N 15TH ST
# ['101 N 15th St', ' 15TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St']
# crime_list 6 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud']
# injury list 6 ['', '', '', '', '', '']
# relationship_list 6 ['None', 'None', 'None', 'None', 'None', 'None']
# address_list 6 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St']
# report_type_list 6 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 6 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST']
# address_list 6 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St']
# date_list 6 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00']
# mainContent_gvSummary_lbGetReport_6
# 2022 1207 Princess St
# ['1207 Princess St']
# 1SP
# 1207 PRINCESS ST
# ['1207 Princess St', 'PRINCESS ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St']
# crime_list 7 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple']
# injury list 7 ['', '', '', '', '', '', 'Apparent Minor Injury']
# relationship_list 7 ['None', 'None', 'None', 'None', 'None', 'None', '1SP']
# address_list 7 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St']
# report_type_list 7 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 7 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST']
# address_list 7 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St']
# date_list 7 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37']
# mainContent_gvSummary_lbGetReport_7
# mainContent_gvSummary_lbGetReport_8
# 2
# 2
# mainContent_gvSummary_lbGetReport_0
# 2022 299 N 13th St
# ['299 N 13th St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St']
# crime_list 8 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations']
# injury list 8 ['', '', '', '', '', '', 'Apparent Minor Injury', '']
# relationship_list 8 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None']
# address_list 8 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St']
# report_type_list 8 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 8 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST']
# address_list 8 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St']
# date_list 8 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21']
# mainContent_gvSummary_lbGetReport_1
# mainContent_gvSummary_lbGetReport_2
# 2022 203 N 11th St
# ['203 N 11th St']
# 1AQ
# 203 N 11TH ST
# ['203 N 11th St', ' 11TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St']
# crime_list 9 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple']
# injury list 9 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury']
# relationship_list 9 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ']
# address_list 9 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St']
# report_type_list 9 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 9 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST']
# address_list 9 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St']
# date_list 9 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57']
# mainContent_gvSummary_lbGetReport_3
# mainContent_gvSummary_lbGetReport_4
# mainContent_gvSummary_lbGetReport_5
# 2022 210 N 11th St
# ['210 N 11th St']
# 210 N 11TH ST
# ['210 N 11th St', ' 11TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St']
# crime_list 10 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop']
# injury list 10 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None']
# relationship_list 10 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None']
# address_list 10 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St']
# report_type_list 10 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 10 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST']
# address_list 10 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St']
# date_list 10 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43']
# mainContent_gvSummary_lbGetReport_6
# mainContent_gvSummary_lbGetReport_7
# 2022 1307 Market St
# ['1307 Market St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St']
# crime_list 11 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop']
# injury list 11 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '']
# relationship_list 11 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None']
# address_list 11 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St']
# report_type_list 11 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 11 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST']
# address_list 11 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St']
# date_list 11 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00']
# mainContent_gvSummary_lbGetReport_8
# 2022 1 N 11th St
# ['1 N 11th St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St']
# crime_list 12 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay']
# injury list 12 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '']
# relationship_list 12 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None']
# address_list 12 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St']
# report_type_list 12 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 12 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST']
# address_list 12 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St']
# date_list 12 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14']
# 3
# 3
# mainContent_gvSummary_lbGetReport_0
# 2022 406 N 12th St
# ['406 N 12th St']
# 1BG
# 1005 Emory St  Wilmington
# ['406 N 12th St', 'Emory St  Wilmington']
# 406 N 12th St  Wilmington
# ['406 N 12th St', 'Emory St  Wilmington', ' 12th St  Wilmington']
# 406 N 7TH ST
# ['406 N 12th St', 'Emory St  Wilmington', ' 12th St  Wilmington', ' 7TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St']
# crime_list 13 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree']
# injury list 13 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None']
# relationship_list 13 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG']
# address_list 13 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St']
# report_type_list 13 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 13 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST']
# address_list 13 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St']
# date_list 13 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39']
# mainContent_gvSummary_lbGetReport_1
# mainContent_gvSummary_lbGetReport_2
# 2022 100 N 12th St
# ['100 N 12th St']
# 3801 GARDEN AV
# ['100 N 12th St', 'GARDEN AV ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St']
# crime_list 14 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop']
# injury list 14 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '']
# relationship_list 14 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None']
# address_list 14 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St']
# report_type_list 14 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 14 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST']
# address_list 14 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St']
# date_list 14 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37']
# mainContent_gvSummary_lbGetReport_3
# 2022 212 N 11th St
# ['212 N 11th St']
# 1RU
# 1102 Grace St  Wilmington
# ['212 N 11th St', 'Grace St  Wilmington']
# 208 N 11TH ST
# ['212 N 11th St', 'Grace St  Wilmington', ' 11TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St']
# crime_list 15 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide']
# injury list 15 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '']
# relationship_list 15 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU']
# address_list 15 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St']
# report_type_list 15 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 15 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST']
# address_list 15 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St']
# date_list 15 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30']
# mainContent_gvSummary_lbGetReport_4
# 2022 401 N 13th St
# ['401 N 13th St']
# 401 N 13th St  Wilmington
# ['401 N 13th St', ' 13th St  Wilmington']
# 1524 S 16TH ST
# ['401 N 13th St', ' 13th St  Wilmington', 'S 16TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St']
# crime_list 16 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property']
# injury list 16 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '']
# relationship_list 16 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None']
# address_list 16 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St']
# report_type_list 16 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 16 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST']
# address_list 16 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St']
# date_list 16 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21']
# mainContent_gvSummary_lbGetReport_5
# mainContent_gvSummary_lbGetReport_6
# mainContent_gvSummary_lbGetReport_7
# 2022 1307 Market St
# ['1307 Market St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St']
# crime_list 17 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations']
# injury list 17 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '']
# relationship_list 17 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None']
# address_list 17 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St']
# report_type_list 17 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 17 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST']
# address_list 17 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St']
# date_list 17 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07']
# mainContent_gvSummary_lbGetReport_8
# 2022 1 N 12th St
# ['1 N 12th St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St']
# crime_list 18 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations', 'Drug Equipment Violations']
# injury list 18 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '', '']
# relationship_list 18 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None', 'None']
# address_list 18 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St']
# report_type_list 18 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 18 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST']
# address_list 18 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St']
# date_list 18 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10']
# 4
# 4
# mainContent_gvSummary_lbGetReport_0
# mainContent_gvSummary_lbGetReport_1
# mainContent_gvSummary_lbGetReport_2
# mainContent_gvSummary_lbGetReport_3
# 2022 212 N 11th St - B
# ['212 N 11th St - B']
# 212 N 11th St  Wilmington
# ['212 N 11th St - B', ' 11th St  Wilmington']
# 212 N 11TH ST
# ['212 N 11th St - B', ' 11th St  Wilmington', ' 11TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B']
# crime_list 19 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations', 'Drug Equipment Violations', 'Death Investigation']
# injury list 19 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '', '', 'None']
# relationship_list 19 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None', 'None', 'None']
# address_list 19 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B']
# report_type_list 19 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 19 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST']
# address_list 19 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B']
# date_list 19 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10', '04/22/2022 23:48']
# mainContent_gvSummary_lbGetReport_4
# 2022 1405 Chestnut St
# ['1405 Chestnut St']
# 1405 CHESTNUT ST
# ['1405 Chestnut St', 'CHESTNUT ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St']
# crime_list 20 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations', 'Drug Equipment Violations', 'Death Investigation', 'B&e Auto Larceny From Auto']
# injury list 20 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '', '', 'None', '']
# relationship_list 20 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None', 'None', 'None', 'None']
# address_list 20 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St']
# report_type_list 20 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 20 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '1400-BLK CHESTNUT ST']
# address_list 20 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St']
# date_list 20 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10', '04/22/2022 23:48', '04/30/2022 05:22']
# mainContent_gvSummary_lbGetReport_5
# mainContent_gvSummary_lbGetReport_6
# 2022 207 N 11th St
# ['207 N 11th St']
# 1RU
# 810 S 16TH ST
# ['207 N 11th St', ' 16TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St']
# crime_list 21 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations', 'Drug Equipment Violations', 'Death Investigation', 'B&e Auto Larceny From Auto', 'Adw']
# injury list 21 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '', '', 'None', '', 'Other Major Injury']
# relationship_list 21 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None', 'None', 'None', 'None', '1RU']
# address_list 21 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St']
# report_type_list 21 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 21 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '1400-BLK CHESTNUT ST', '200-BLK N 11TH ST']
# address_list 21 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St']
# date_list 21 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10', '04/22/2022 23:48', '04/30/2022 05:22', '05/01/2022 09:50']
# mainContent_gvSummary_lbGetReport_7
# 2022 207 N 11th St
# ['207 N 11th St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St']
# crime_list 22 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations', 'Drug Equipment Violations', 'Death Investigation', 'B&e Auto Larceny From Auto', 'Adw', 'Drug/narcotic Violations']
# injury list 22 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '', '', 'None', '', 'Other Major Injury', '']
# relationship_list 22 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None', 'None', 'None', 'None', '1RU', 'None']
# address_list 22 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St']
# report_type_list 22 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 22 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '1400-BLK CHESTNUT ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST']
# address_list 22 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St']
# date_list 22 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10', '04/22/2022 23:48', '04/30/2022 05:22', '05/01/2022 09:50', '05/01/2022 09:50']
# mainContent_gvSummary_lbGetReport_8
# 2022 242 N 11th St
# ['242 N 11th St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St']
# crime_list 23 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations', 'Drug Equipment Violations', 'Death Investigation', 'B&e Auto Larceny From Auto', 'Adw', 'Drug/narcotic Violations', 'Drug/narcotic Violations']
# injury list 23 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '', '', 'None', '', 'Other Major Injury', '', '']
# relationship_list 23 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None', 'None', 'None', 'None', '1RU', 'None', 'None']
# address_list 23 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St']
# report_type_list 23 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 23 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '1400-BLK CHESTNUT ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST']
# address_list 23 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St']
# date_list 23 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10', '04/22/2022 23:48', '04/30/2022 05:22', '05/01/2022 09:50', '05/01/2022 09:50', '05/03/2022 20:40']
# 5
# 5
# mainContent_gvSummary_lbGetReport_0
# mainContent_gvSummary_lbGetReport_1
# mainContent_gvSummary_lbGetReport_2
# mainContent_gvSummary_lbGetReport_3
# mainContent_gvSummary_lbGetReport_4
# mainContent_gvSummary_lbGetReport_5
# mainContent_gvSummary_lbGetReport_6
# 2022 100 N 13th St
# ['100 N 13th St']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St', '100 N 13th St']
# ...
# address_list 53 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St', '100 N 13th St', '309 N 14th St', '100 N 13th St', '1215 Grace St', '1215 Grace St', '1007 Chestnut St', '214 N 11th St', '214 N 11th St', '204 N 13th St', '1100 Market St', '207 N 11th St', '1205 Walnut St', '1 S 11th St', '208 N 11th St', '1205 Walnut St', '1109 Grace St', '209 N 14th St', '1500 Chestnut St', '209 N 14th St - A', '279 N 12th St', '1207 Chestnut St', '1 N 11th St', '1123 Princess St', '1199 Chestnut St', '209 N 14th St', '1300 Market St', 'None', '1020 Princess St', '1201 Princess St', '1104 Grace St']
# report_type_list 53 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 53 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '1400-BLK CHESTNUT ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '100-BLK N 13TH ST', '300-BLK N 14TH ST', '100-BLK N 13TH ST', '1200-BLK GRACE ST', '1200-BLK GRACE ST', '1000-BLK CHESTNUT ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '200-BLK N 13TH ST', '1100-BLK MARKET ST', '200-BLK N 11TH ST', '1200-BLK WALNUT ST', '100-BLK S 11TH ST', '200-BLK N 11TH ST', '1200-BLK WALNUT ST', '1100-BLK GRACE ST', '200-BLK N 14TH ST', '1500-BLK CHESTNUT ST', '200-BLK N 14TH ST', '200-BLK N 12TH ST', '1200-BLK CHESTNUT ST', '100-BLK N 11TH ST', '1100-BLK PRINCESS ST', '1100-BLK CHESTNUT ST', '200-BLK N 14TH ST', '1300-BLK MARKET ST', '200-BLK N 12TH ST', '1000-BLK PRINCESS ST', '1200-BLK PRINCESS ST', '1100-BLK GRACE ST']
# address_list 53 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St', '100 N 13th St', '309 N 14th St', '100 N 13th St', '1215 Grace St', '1215 Grace St', '1007 Chestnut St', '214 N 11th St', '214 N 11th St', '204 N 13th St', '1100 Market St', '207 N 11th St', '1205 Walnut St', '1 S 11th St', '208 N 11th St', '1205 Walnut St', '1109 Grace St', '209 N 14th St', '1500 Chestnut St', '209 N 14th St - A', '279 N 12th St', '1207 Chestnut St', '1 N 11th St', '1123 Princess St', '1199 Chestnut St', '209 N 14th St', '1300 Market St', 'None', '1020 Princess St', '1201 Princess St', '1104 Grace St']
# date_list 53 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10', '04/22/2022 23:48', '04/30/2022 05:22', '05/01/2022 09:50', '05/01/2022 09:50', '05/03/2022 20:40', '05/11/2022 17:00', '05/13/2022 16:00', '05/18/2022 20:27', '05/31/2022 22:00', '05/31/2022 22:00', '06/08/2022 21:00', '06/12/2022 20:00', '06/17/2022 15:50', '06/22/2022 08:55', '07/12/2022 03:44', '07/17/2022 01:30', '07/23/2022 00:30', '07/24/2022 18:20', '08/03/2022 20:11', '08/11/2022 06:30', '08/13/2022 09:07', '08/19/2022 07:58', '09/10/2022 03:17', '09/15/2022 20:21', '09/19/2022 21:47', '09/28/2021 13:00', '10/04/2021 21:24', '10/12/2021 20:00', '10/19/2021 09:27', '11/01/2021 12:00', '11/10/2021 15:05', '11/18/2021 22:26', '12/03/2021 22:20', '12/12/2021 21:42', '12/12/2021 22:04']
# mainContent_gvSummary_lbGetReport_7
# mainContent_gvSummary_lbGetReport_8
# 2021 1107 Chestnut St
# ['1107 Chestnut St']
# 612 S 14TH ST
# ['1107 Chestnut St', ' 14TH ST ']
# ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St', '100 N 13th St', '309 N 14th St', '100 N 13th St', '1215 Grace St', '1215 Grace St', '1007 Chestnut St', '214 N 11th St', '214 N 11th St', '204 N 13th St', '1100 Market St', '207 N 11th St', '1205 Walnut St', '1 S 11th St', '208 N 11th St', '1205 Walnut St', '1109 Grace St', '209 N 14th St', '1500 Chestnut St', '209 N 14th St - A', '279 N 12th St', '1207 Chestnut St', '1 N 11th St', '1123 Princess St', '1199 Chestnut St', '209 N 14th St', '1300 Market St', 'None', '1020 Princess St', '1201 Princess St', '1104 Grace St', '1107 Chestnut St']
# crime_list 54 ['Dwi - Alcohol', 'Death Investigation', 'Larceny-outside Of Build (not For Sale)', 'B&e Felony', 'Mv Theft', 'Financial Transaction Card Fraud', 'Assault-simple', 'Drug/narcotic Violations', 'Assault-simple', 'Hit & Run-misd Fail To Stop', 'Hit & Run-misd Fail To Stop', 'Resisting Arrest/hinder & Delay', 'Trespass-second Degree', 'Hit & Run-misd Fail To Stop', 'Homicide', 'Damage To Real Property', 'Drug/narcotic Violations', 'Drug Equipment Violations', 'Death Investigation', 'B&e Auto Larceny From Auto', 'Adw', 'Drug/narcotic Violations', 'Drug/narcotic Violations', 'Drug/narcotic Violations', 'Mv Theft', 'Drug/narcotic Violations', 'Larceny-outside Of Build (not For Sale)', 'Larceny-outside Of Build (not For Sale)', 'B&e Auto Larceny From Auto', 'Death Investigation', 'Firearm By Felon', 'Miscellaneous', 'Drug/narcotic Violations', 'Damage Personal Property Offenses', 'Mv Theft', 'Resisting Arrest/hinder & Delay', 'Simple Assault Offenses', 'Drug/narcotic Violations', 'Fraud - Financial Card', 'Recovered Vehicle', 'Hit & Run-misd Fail To Stop', 'Burglary/b&e Offenses', 'Drug/narcotic Violations', 'Missing Persons', 'Drive While License Revoked/not Impaired Rev -', 'B&e Felony', 'Miscellaneous', 'Obtain Property By False Pretense', 'Dwi - Alcohol', 'Drug/narcotic Violations', 'Larceny From Auto', 'B&e Felony', 'Assault-simple', 'B&e Auto Larceny From Auto']
# injury list 54 ['', '', '', '', '', '', 'Apparent Minor Injury', '', 'Apparent Minor Injury', 'None', '', '', 'None', '', '', '', '', '', 'None', '', 'Other Major Injury', '', '', '', '', '', '', '', '', '', ' 07/28/2022', '', '', '', '', '', 'Apparent Minor Injury', '', '', '', '', 'None', '', '', '', '', '', '', '', '', 'None', '', 'Apparent Minor Injury', '']
# relationship_list 54 ['None', 'None', 'None', 'None', 'None', 'None', '1SP', 'None', '1AQ', 'None', 'None', 'None', '1BG', 'None', '1RU', 'None', 'None', 'None', 'None', 'None', '1RU', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '1OK', 'None', 'None', '1RU', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# address_list 54 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St', '100 N 13th St', '309 N 14th St', '100 N 13th St', '1215 Grace St', '1215 Grace St', '1007 Chestnut St', '214 N 11th St', '214 N 11th St', '204 N 13th St', '1100 Market St', '207 N 11th St', '1205 Walnut St', '1 S 11th St', '208 N 11th St', '1205 Walnut St', '1109 Grace St', '209 N 14th St', '1500 Chestnut St', '209 N 14th St - A', '279 N 12th St', '1207 Chestnut St', '1 N 11th St', '1123 Princess St', '1199 Chestnut St', '209 N 14th St', '1300 Market St', 'None', '1020 Princess St', '1201 Princess St', '1104 Grace St', '1107 Chestnut St']
# report_type_list 54 ['Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident', 'Incident']
# block_list 54 ['1100-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 13TH ST', '1100-BLK GRACE ST', '200-BLK N 13TH ST', '100-BLK N 15TH ST', '1200-BLK PRINCESS ST', '200-BLK N 13TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '1300-BLK MARKET ST', '100-BLK N 11TH ST', '400-BLK N 12TH ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '400-BLK N 13TH ST', '1300-BLK MARKET ST', '100-BLK N 12TH ST', '200-BLK N 11TH ST', '1400-BLK CHESTNUT ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '100-BLK N 13TH ST', '300-BLK N 14TH ST', '100-BLK N 13TH ST', '1200-BLK GRACE ST', '1200-BLK GRACE ST', '1000-BLK CHESTNUT ST', '200-BLK N 11TH ST', '200-BLK N 11TH ST', '200-BLK N 13TH ST', '1100-BLK MARKET ST', '200-BLK N 11TH ST', '1200-BLK WALNUT ST', '100-BLK S 11TH ST', '200-BLK N 11TH ST', '1200-BLK WALNUT ST', '1100-BLK GRACE ST', '200-BLK N 14TH ST', '1500-BLK CHESTNUT ST', '200-BLK N 14TH ST', '200-BLK N 12TH ST', '1200-BLK CHESTNUT ST', '100-BLK N 11TH ST', '1100-BLK PRINCESS ST', '1100-BLK CHESTNUT ST', '200-BLK N 14TH ST', '1300-BLK MARKET ST', '200-BLK N 12TH ST', '1000-BLK PRINCESS ST', '1200-BLK PRINCESS ST', '1100-BLK GRACE ST', '1100-BLK CHESTNUT ST']
# address_list 54 ['1100 Market St', '107 N 12th St', '202 N 13th St', '1109 Grace St', '204 N 13th St', '101 N 15th St', '1207 Princess St', '299 N 13th St', '203 N 11th St', '210 N 11th St', '1307 Market St', '1 N 11th St', '406 N 12th St', '100 N 12th St', '212 N 11th St', '401 N 13th St', '1307 Market St', '1 N 12th St', '212 N 11th St - B', '1405 Chestnut St', '207 N 11th St', '207 N 11th St', '242 N 11th St', '100 N 13th St', '309 N 14th St', '100 N 13th St', '1215 Grace St', '1215 Grace St', '1007 Chestnut St', '214 N 11th St', '214 N 11th St', '204 N 13th St', '1100 Market St', '207 N 11th St', '1205 Walnut St', '1 S 11th St', '208 N 11th St', '1205 Walnut St', '1109 Grace St', '209 N 14th St', '1500 Chestnut St', '209 N 14th St - A', '279 N 12th St', '1207 Chestnut St', '1 N 11th St', '1123 Princess St', '1199 Chestnut St', '209 N 14th St', '1300 Market St', 'None', '1020 Princess St', '1201 Princess St', '1104 Grace St', '1107 Chestnut St']
# date_list 54 ['01/02/2022 01:20', '01/09/2022 21:03', '01/23/2022 21:00', '01/28/2022 08:00', '02/03/2022 00:30', '02/03/2022 09:00', '02/06/2022 15:37', '02/26/2022 22:21', '03/15/2022 15:57', '03/20/2022 12:43', '03/22/2022 14:00', '03/27/2022 19:14', '04/02/2022 12:39', '04/04/2022 09:37', '04/05/2022 14:30', '04/06/2022 16:21', '04/17/2022 21:07', '04/22/2022 00:10', '04/22/2022 23:48', '04/30/2022 05:22', '05/01/2022 09:50', '05/01/2022 09:50', '05/03/2022 20:40', '05/11/2022 17:00', '05/13/2022 16:00', '05/18/2022 20:27', '05/31/2022 22:00', '05/31/2022 22:00', '06/08/2022 21:00', '06/12/2022 20:00', '06/17/2022 15:50', '06/22/2022 08:55', '07/12/2022 03:44', '07/17/2022 01:30', '07/23/2022 00:30', '07/24/2022 18:20', '08/03/2022 20:11', '08/11/2022 06:30', '08/13/2022 09:07', '08/19/2022 07:58', '09/10/2022 03:17', '09/15/2022 20:21', '09/19/2022 21:47', '09/28/2021 13:00', '10/04/2021 21:24', '10/12/2021 20:00', '10/19/2021 09:27', '11/01/2021 12:00', '11/10/2021 15:05', '11/18/2021 22:26', '12/03/2021 22:20', '12/12/2021 21:42', '12/12/2021 22:04', '12/21/2021 16:00']
# 11
# ...
# mainContent_gvSummary_lbGetReport_0
# 12
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [19], in <cell line: 24>()
#     134 current_page += 1
#     135 print(current_page)
# --> 136 new_page = driver.find_element(By.XPATH, f'//a[@href = "javascript:__doPostBack(\'MasterPage$mainContent$gvSummary\',\'Page${current_page}\')"]')
#     137 print(new_page.text)
#     138 driver.execute_script("arguments[0].click()", new_page)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:434, in WebDriver.execute(self, driver_command, params)
#     432 response = self.command_executor.execute(driver_command, params)
#     433 if response:
# --> 434     self.error_handler.check_response(response)
#     435     response['value'] = self._unwrap_value(
#     436         response.get('value', None))
#     437     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//a[@href = "javascript:__doPostBack('MasterPage$mainContent$gvSummary','Page$12')"]"}
#   (Session info: headless chrome=105.0.5195.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0025DF13+2219795]
# 	Ordinal0 [0x001F2841+1779777]
# 	Ordinal0 [0x0010423D+803389]
# 	Ordinal0 [0x00133025+995365]
# 	Ordinal0 [0x001331EB+995819]
# 	Ordinal0 [0x00160F52+1183570]
# 	Ordinal0 [0x0014E844+1108036]
# 	Ordinal0 [0x0015F192+1175954]
# 	Ordinal0 [0x0014E616+1107478]
# 	Ordinal0 [0x00127F89+950153]
# 	Ordinal0 [0x00128F56+954198]
# 	GetHandleVerifier [0x00552CB2+3040210]
# 	GetHandleVerifier [0x00542BB4+2974420]
# 	GetHandleVerifier [0x002F6A0A+565546]
# 	GetHandleVerifier [0x002F5680+560544]
# 	Ordinal0 [0x001F9A5C+1808988]
# 	Ordinal0 [0x001FE3A8+1827752]
# 	Ordinal0 [0x001FE495+1827989]
# 	Ordinal0 [0x002080A4+1867940]
# 	BaseThreadInitThunk [0x77586739+25]
# 	RtlGetFullPathName_UEx [0x77778FD2+1218]
# 	RtlGetFullPathName_UEx [0x77778F9D+1165]
# 	(No symbol) [0x00000000]

# %%
complete_list = [crime_list, injury_list, relationship_list, report_type_list, block_list, address_list, date_list]
for list in complete_list:
    print(len(list))
# Out:
# 54
# 54
# 54
# 54
# 54
# 54
# 54

# %%
complete_list = [crime_list, injury_list, relationship_list, report_type_list, block_list, address_list, date_list]
df = pd.DataFrame(tuple(zip(crime_list, injury_list, relationship_list, report_type_list, block_list, address_list, date_list)), columns = ['crime', 'injury', 'relationship', 'report_type', 'block', 'address', 'date'])
df.loc[df['crime'].str.contains('larceny', case=False)]
# Out:
#                                       crime injury relationship report_type  \
# 2   Larceny-outside Of Build (not For Sale)                None    Incident
# 19               B&e Auto Larceny From Auto                None    Incident
# 26  Larceny-outside Of Build (not For Sale)                None    Incident
# 27  Larceny-outside Of Build (not For Sale)                None    Incident
# 28               B&e Auto Larceny From Auto                None    Incident
# 50                        Larceny From Auto   None         None    Incident
# 53               B&e Auto Larceny From Auto                None    Incident
#
#                    block           address              date
# 2      200-BLK N 13TH ST     202 N 13th St  01/23/2022 21:00
# 19  1400-BLK CHESTNUT ST  1405 Chestnut St  04/30/2022 05:22
# 26     1200-BLK GRACE ST     1215 Grace St  05/31/2022 22:00
# 27     1200-BLK GRACE ST     1215 Grace St  05/31/2022 22:00
# 28  1000-BLK CHESTNUT ST  1007 Chestnut St  06/08/2022 21:00
# 50  1000-BLK PRINCESS ST  1020 Princess St  12/03/2021 22:20
# 53  1100-BLK CHESTNUT ST  1107 Chestnut St  12/21/2021 16:00

# %%
browser.close()
